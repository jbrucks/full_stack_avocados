# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime
from datetime import timedelta
# from config import password
# password = password

# %%
loadweather = "SDweather.csv"

# %%
initSDweather_df = pd.read_csv(loadweather)

# %%
initSDweather_df.head()
# Out:
#            dt                         dt_iso  timezone  city_name        lat  \
# 0  1420070400  2015-01-01 00:00:00 +0000 UTC    -28800  San Diego  32.715738
# 1  1420074000  2015-01-01 01:00:00 +0000 UTC    -28800  San Diego  32.715738
# 2  1420077600  2015-01-01 02:00:00 +0000 UTC    -28800  San Diego  32.715738
# 3  1420081200  2015-01-01 03:00:00 +0000 UTC    -28800  San Diego  32.715738
# 4  1420084800  2015-01-01 04:00:00 +0000 UTC    -28800  San Diego  32.715738
#
#           lon   temp  feels_like  temp_min  temp_max  ...  wind_deg  rain_1h  \
# 0 -117.161084  51.37       43.63     49.09     52.83  ...       280      NaN
# 1 -117.161084  50.05       41.99     47.80     53.22  ...       340      NaN
# 2 -117.161084  46.72       40.64     39.92     53.62  ...       342      NaN
# 3 -117.161084  45.19       39.15     39.92     54.01  ...        14      NaN
# 4 -117.161084  43.88       37.85     37.94     54.27  ...        28      NaN
#
#    rain_3h  snow_1h  snow_3h  clouds_all  weather_id  weather_main  \
# 0      NaN      NaN      NaN          40         802        Clouds
# 1      NaN      NaN      NaN          40         802        Clouds
# 2      NaN      NaN      NaN          20         801        Clouds
# 3      NaN      NaN      NaN          20         801        Clouds
# 4      NaN      NaN      NaN          20         801        Clouds
#
#    weather_description  weather_icon
# 0     scattered clouds           03d
# 1     scattered clouds           03n
# 2           few clouds           02n
# 3           few clouds           02n
# 4           few clouds           02n
#
# [5 rows x 25 columns]

# %%
# initSDweather_df.columns = (initSDweather_df.columns.str.strip().str.upper()
#               .str.replace(' ', '_')
#               .str.replace('(', '')
#               .str.replace(')', ''))

# %%
# initSDweather_df.head()

# %%
# tot_transport_columns = ["Date", "Origin", "Destination", "Distance", "Commodity", "Week Low", "Week High", "Midpoint", "Rate Per Mile", "Availability"]
# tot_transport_df = initial_transport_df[tot_transport_columns].copy()

# # Rename the column headers
# tot_transport_df = tot_transport_df.rename(columns={"Date": "date",
#                                                         "Origin": "origin",
#                                                         "Destination": "destination",
#                                                        "Distance": "transport_distance",
#                                                        "Commodity": "commodity",
#                                                        "Week Low": "low_weekly_rate",
#                                                        "Week High": "high_weekly_rate",
#                                                        "Midpoint": "average_weekly_rate",
#                                                        "Rate Per Mile": "avg_rate_per_mile_ratio",
#                                                        "Availability": "availability_score"
#                                                    })

# %%
# SDweather_columns = ["date", "temp", "rain_1h", "rain_3h", "snow_1h", "snow_3h", "weather_type"]
# SDweather_df = initSDweather_df[SDweather_columns].copy()

# SDweather_df = SDweather_df.rename(columns={"date": "DT",
#                                                 "temp": "TEMP	",
#                                                 "rain_1h": "RAIN_1H",
#                                                 "rain_3h": "RAIN_3H	",
#                                                 "snow_1h": "SNOW_1H",
#                                                 "snow_3h": "SNOW_3H",
#                                                 "weather_type": "WEATHER_DESCRIPTION"
#                                            })

# %%
SDweather_df = initSDweather_df[["dt", "temp", "rain_1h", "rain_3h", "snow_1h", "snow_3h", "weather_description"]]
SDweather_df
# Out:
#                dt   temp  rain_1h  rain_3h  snow_1h  snow_3h  \
# 0      1420070400  51.37      NaN      NaN      NaN      NaN
# 1      1420074000  50.05      NaN      NaN      NaN      NaN
# 2      1420077600  46.72      NaN      NaN      NaN      NaN
# 3      1420081200  45.19      NaN      NaN      NaN      NaN
# 4      1420084800  43.88      NaN      NaN      NaN      NaN
# ...           ...    ...      ...      ...      ...      ...
# 34516  1543690800  63.37      NaN      NaN      NaN      NaN
# 34517  1543694400  63.79      NaN      NaN      NaN      NaN
# 34518  1543698000  64.74      NaN      NaN      NaN      NaN
# 34519  1543701600  64.87      NaN      NaN      NaN      NaN
# 34520  1543705200  63.54      NaN      NaN      NaN      NaN
#
#       weather_description
# 0        scattered clouds
# 1        scattered clouds
# 2              few clouds
# 3              few clouds
# 4              few clouds
# ...                   ...
# 34516       broken clouds
# 34517       broken clouds
# 34518       broken clouds
# 34519       broken clouds
# 34520       broken clouds
#
# [34521 rows x 7 columns]

# %%
# tot_transport_df['date'] = pd.to_datetime(tot_transport_df['date'])
SDweather_df["dt"] = pd.to_datetime(SDweather_df["dt"], unit="s")
SDweather_df
# Out:
# C:\Users\rober\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        dt   temp  rain_1h  rain_3h  snow_1h  snow_3h  \
# 0     2015-01-01 00:00:00  51.37      NaN      NaN      NaN      NaN
# 1     2015-01-01 01:00:00  50.05      NaN      NaN      NaN      NaN
# 2     2015-01-01 02:00:00  46.72      NaN      NaN      NaN      NaN
# 3     2015-01-01 03:00:00  45.19      NaN      NaN      NaN      NaN
# 4     2015-01-01 04:00:00  43.88      NaN      NaN      NaN      NaN
# ...                   ...    ...      ...      ...      ...      ...
# 34516 2018-12-01 19:00:00  63.37      NaN      NaN      NaN      NaN
# 34517 2018-12-01 20:00:00  63.79      NaN      NaN      NaN      NaN
# 34518 2018-12-01 21:00:00  64.74      NaN      NaN      NaN      NaN
# 34519 2018-12-01 22:00:00  64.87      NaN      NaN      NaN      NaN
# 34520 2018-12-01 23:00:00  63.54      NaN      NaN      NaN      NaN
#
#       weather_description
# 0        scattered clouds
# 1        scattered clouds
# 2              few clouds
# 3              few clouds
# 4              few clouds
# ...                   ...
# 34516       broken clouds
# 34517       broken clouds
# 34518       broken clouds
# 34519       broken clouds
# 34520       broken clouds
#
# [34521 rows x 7 columns]

# %%
SDweather_df = SDweather_df.set_index("dt")
SDweather_df
# Out:
#                       temp  rain_1h  rain_3h  snow_1h  snow_3h  \
# dt
# 2015-01-01 00:00:00  51.37      NaN      NaN      NaN      NaN
# 2015-01-01 01:00:00  50.05      NaN      NaN      NaN      NaN
# 2015-01-01 02:00:00  46.72      NaN      NaN      NaN      NaN
# 2015-01-01 03:00:00  45.19      NaN      NaN      NaN      NaN
# 2015-01-01 04:00:00  43.88      NaN      NaN      NaN      NaN
# ...                    ...      ...      ...      ...      ...
# 2018-12-01 19:00:00  63.37      NaN      NaN      NaN      NaN
# 2018-12-01 20:00:00  63.79      NaN      NaN      NaN      NaN
# 2018-12-01 21:00:00  64.74      NaN      NaN      NaN      NaN
# 2018-12-01 22:00:00  64.87      NaN      NaN      NaN      NaN
# 2018-12-01 23:00:00  63.54      NaN      NaN      NaN      NaN
#
#                     weather_description
# dt
# 2015-01-01 00:00:00    scattered clouds
# 2015-01-01 01:00:00    scattered clouds
# 2015-01-01 02:00:00          few clouds
# 2015-01-01 03:00:00          few clouds
# 2015-01-01 04:00:00          few clouds
# ...                                 ...
# 2018-12-01 19:00:00       broken clouds
# 2018-12-01 20:00:00       broken clouds
# 2018-12-01 21:00:00       broken clouds
# 2018-12-01 22:00:00       broken clouds
# 2018-12-01 23:00:00       broken clouds
#
# [34521 rows x 6 columns]

# %%
# SDweather_df.dropna()
# SDweather_df

# %%
SDweather_df.tail(50)
# Out:
#                       temp  rain_1h  rain_3h  snow_1h  snow_3h  \
# dt
# 2018-11-29 22:00:00  61.41     0.43      NaN      NaN      NaN
# 2018-11-29 23:00:00  62.40     1.43      NaN      NaN      NaN
# 2018-11-30 00:00:00  62.76     2.70      NaN      NaN      NaN
# 2018-11-30 01:00:00  61.54     0.30      NaN      NaN      NaN
# 2018-11-30 02:00:00  62.20      NaN      NaN      NaN      NaN
# 2018-11-30 03:00:00  62.17      NaN      0.3      NaN      NaN
# 2018-11-30 04:00:00  62.64      NaN      NaN      NaN      NaN
# 2018-11-30 05:00:00  61.29      NaN      NaN      NaN      NaN
# 2018-11-30 06:00:00  61.27      NaN      NaN      NaN      NaN
# 2018-11-30 07:00:00  59.07     3.37      NaN      NaN      NaN
# 2018-11-30 08:00:00  58.73     1.00      NaN      NaN      NaN
# 2018-11-30 09:00:00  59.54     0.90      4.6      NaN      NaN
# 2018-11-30 10:00:00  60.48     0.77      NaN      NaN      NaN
# 2018-11-30 11:00:00  60.49      NaN      NaN      NaN      NaN
# 2018-11-30 12:00:00  60.76      NaN      NaN      NaN      NaN
# 2018-11-30 13:00:00  60.04     0.50      NaN      NaN      NaN
# 2018-11-30 14:00:00  60.40     0.50      NaN      NaN      NaN
# 2018-11-30 15:00:00  60.48     0.80      0.9      NaN      NaN
# 2018-11-30 16:00:00  61.77     0.50      NaN      NaN      NaN
# 2018-11-30 17:00:00  63.16      NaN      NaN      NaN      NaN
# 2018-11-30 18:00:00  63.52      NaN      NaN      NaN      NaN
# 2018-11-30 19:00:00  64.13      NaN      NaN      NaN      NaN
# 2018-11-30 20:00:00  64.56      NaN      NaN      NaN      NaN
# 2018-11-30 21:00:00  64.40      NaN      NaN      NaN      NaN
# 2018-11-30 22:00:00  64.02      NaN      NaN      NaN      NaN
# 2018-11-30 23:00:00  63.72      NaN      NaN      NaN      NaN
# 2018-12-01 00:00:00  62.58      NaN      NaN      NaN      NaN
# 2018-12-01 01:00:00  61.79      NaN      NaN      NaN      NaN
# 2018-12-01 02:00:00  61.47      NaN      NaN      NaN      NaN
# 2018-12-01 03:00:00  60.76      NaN      NaN      NaN      NaN
# 2018-12-01 04:00:00  60.33      NaN      NaN      NaN      NaN
# 2018-12-01 05:00:00  59.65      NaN      NaN      NaN      NaN
# 2018-12-01 06:00:00  59.00      NaN      NaN      NaN      NaN
# 2018-12-01 07:00:00  58.44      NaN      NaN      NaN      NaN
# 2018-12-01 08:00:00  58.06      NaN      NaN      NaN      NaN
# 2018-12-01 09:00:00  57.90      NaN      NaN      NaN      NaN
# 2018-12-01 10:00:00  57.16      NaN      NaN      NaN      NaN
# 2018-12-01 11:00:00  55.69      NaN      NaN      NaN      NaN
# 2018-12-01 12:00:00  55.27      NaN      NaN      NaN      NaN
# 2018-12-01 13:00:00  55.18      NaN      NaN      NaN      NaN
# 2018-12-01 14:00:00  55.38      NaN      NaN      NaN      NaN
# 2018-12-01 15:00:00  55.20      NaN      NaN      NaN      NaN
# 2018-12-01 16:00:00  57.13      NaN      NaN      NaN      NaN
# 2018-12-01 17:00:00  60.21      NaN      NaN      NaN      NaN
# 2018-12-01 18:00:00  62.22      NaN      NaN      NaN      NaN
# 2018-12-01 19:00:00  63.37      NaN      NaN      NaN      NaN
# 2018-12-01 20:00:00  63.79      NaN      NaN      NaN      NaN
# 2018-12-01 21:00:00  64.74      NaN      NaN      NaN      NaN
# 2018-12-01 22:00:00  64.87      NaN      NaN      NaN      NaN
# 2018-12-01 23:00:00  63.54      NaN      NaN      NaN      NaN
#
#                     weather_description
# dt
# 2018-11-29 22:00:00          light rain
# 2018-11-29 23:00:00       moderate rain
# 2018-11-30 00:00:00       moderate rain
# 2018-11-30 01:00:00          light rain
# 2018-11-30 02:00:00       broken clouds
# 2018-11-30 03:00:00          light rain
# 2018-11-30 04:00:00       broken clouds
# 2018-11-30 05:00:00    scattered clouds
# 2018-11-30 06:00:00    scattered clouds
# 2018-11-30 07:00:00       moderate rain
# 2018-11-30 08:00:00          light rain
# 2018-11-30 09:00:00          light rain
# 2018-11-30 10:00:00          light rain
# 2018-11-30 11:00:00       broken clouds
# 2018-11-30 12:00:00     overcast clouds
# 2018-11-30 13:00:00          light rain
# 2018-11-30 14:00:00          light rain
# 2018-11-30 15:00:00          light rain
# 2018-11-30 16:00:00          light rain
# 2018-11-30 17:00:00       broken clouds
# 2018-11-30 18:00:00    scattered clouds
# 2018-11-30 19:00:00       broken clouds
# 2018-11-30 20:00:00       broken clouds
# 2018-11-30 21:00:00       broken clouds
# 2018-11-30 22:00:00       broken clouds
# 2018-11-30 23:00:00       broken clouds
# 2018-12-01 00:00:00    scattered clouds
# 2018-12-01 01:00:00       broken clouds
# 2018-12-01 02:00:00       broken clouds
# 2018-12-01 03:00:00       broken clouds
# 2018-12-01 04:00:00       broken clouds
# 2018-12-01 05:00:00       broken clouds
# 2018-12-01 06:00:00    scattered clouds
# 2018-12-01 07:00:00       broken clouds
# 2018-12-01 08:00:00       broken clouds
# 2018-12-01 09:00:00       broken clouds
# 2018-12-01 10:00:00    scattered clouds
# 2018-12-01 11:00:00    scattered clouds
# 2018-12-01 12:00:00    scattered clouds
# 2018-12-01 13:00:00       broken clouds
# 2018-12-01 14:00:00       broken clouds
# 2018-12-01 15:00:00       broken clouds
# 2018-12-01 16:00:00       broken clouds
# 2018-12-01 17:00:00       broken clouds
# 2018-12-01 18:00:00    scattered clouds
# 2018-12-01 19:00:00       broken clouds
# 2018-12-01 20:00:00       broken clouds
# 2018-12-01 21:00:00       broken clouds
# 2018-12-01 22:00:00       broken clouds
# 2018-12-01 23:00:00       broken clouds

# %%
SDweather_df.to_csv(index=False)
# Out:
# 'temp,rain_1h,rain_3h,snow_1h,snow_3h,weather_description\r\n51.37,,,,,scattered clouds\r\n50.05,,,,,scattered clouds\r\n46.72,,,,,few clouds\r\n45.19,,,,,few clouds\r\n43.88,,,,,few clouds\r\n42.89,,,,,few clouds\r\n42.44,,,,,few clouds\r\n41.07,,,,,sky is clear\r\n40.66,,,,,sky is clear\r\n40.96,,,,,sky is clear\r\n39.99,,,,,sky is clear\r\n40.5,,,,,sky is clear\r\n40.12,,,,,sky is clear\r\n39.51,,,,,sky is clear\r\n39.65,,,,,sky is clear\r\n40.17,,,,,sky is clear\r\n42.82,,,,,few clouds\r\n47.01,,,,,few clouds\r\n50.9,,,,,few clouds\r\n54.05,,,,,few clouds\r\n55.36,,,,,few clouds\r\n56.88,,,,,few clouds\r\n57.65,,,,,few clouds\r\n57.02,,,,,few clouds\r\n56.41,,,,,few clouds\r\n54.39,,,,,few clouds\r\n52.38,,,,,few clouds\r\n50.49,,,,,sky is clear\r\n48.38,,,,,sky is clear\r\n47.34,,,,,sky is clear\r\n46.78,,,,,sky is clear\r\n45.79,,,,,sky is clear\r\n45.3,,,,,sky is clear\r\n43.77,,,,,sky is clear\r\n43.36,,,,,sky is clear\r\n42.46,,,,,sky is clear\r\n40.55,,,,,sky is clear\r\n39.85,,,,,sky is clear\r\n40.55,,,,,sky is clear\r\n40.41,,,,,sky is clear\r\n43.52,,,,,few clouds\r\n49.37,,,,,sky is clear\r\n53.11,,,,,sky is clear\r\n55.11,,,,,sky is clear\r\n57.52,,,,,sky is clear\r\n58.01,,,,,sky is clear\r\n57.7,,,,,sky is clear\r\n57.24,,,,,sky is clear\r\n56.01,,,,,few clouds\r\n54.68,,,,,scattered clouds\r\n53.15,,,,,scattered clouds\r\n50.18,,,,,scattered clouds\r\n48.52,,,,,scattered clouds\r\n49.14,,,,,scattered clouds\r\n48.6,,,,,few clouds\r\n48.13,,,,,sky is clear\r\n46.63,,,,,sky is clear\r\n46.87,,,,,few clouds\r\n45.54,,,,,scattered clouds\r\n45.68,,,,,few clouds\r\n44.74,,,,,few clouds\r\n43.97,,,,,few clouds\r\n43.72,,,,,sky is clear\r\n43.7,,,,,few clouds\r\n46.54,,,,,few clouds\r\n51.15,,,,,few clouds\r\n54.21,,,,,sky is clear\r\n57.25,,,,,few clouds\r\n58.8,,,,,sky is clear\r\n60.35,,,,,few clouds\r\n60.42,,,,,few clouds\r\n59.85,,,,,few clouds\r\n58.6,,,,,few clouds\r\n56.73,,,,,few clouds\r\n55.51,,,,,few clouds\r\n53.01,,,,,few clouds\r\n51.49,,,,,few clouds\r\n49.84,,,,,few clouds\r\n49.73,,,,,few clouds\r\n48.51,,,,,sky is clear\r\n48.02,,,,,sky is clear\r\n47.08,,,,,sky is clear\r\n45.93,,,,,sky is clear\r\n45.57,,,,,sky is clear\r\n45.52,,,,,sky is clear\r\n44.49,,,,,sky is clear\r\n43.95,,,,,sky is clear\r\n43.9,,,,,few clouds\r\n47.5,,,,,few clouds\r\n53.78,,,,,few clouds\r\n58.35,,,,,few clouds\r\n61.54,,,,,few clouds\r\n63.7,,,,,scattered clouds\r\n64.26,,,,,scattered clouds\r\n64.45,,,,,scattered clouds\r\n64.67,,,,,broken clouds\r\n62.31,,,,,scattered clouds\r\n60.51,,,,,broken clouds\r\n58.86,,,,,broken clouds\r\n57.31,,,,,scattered clouds\r\n54.95,,,,,haze\r\n53.82,,,,,haze\r\n53.01,,,,,haze\r\n52.05,,,,,haze\r\n51.24,,,,,mist\r\n50.36,,,,,mist\r\n49.73,,,,,mist\r\n49.28,,,,,few clouds\r\n49.12,,,,,sky is clear\r\n48.56,,,,,sky is clear\r\n48.4,,,,,sky is clear\r\n48.18,,,,,scattered clouds\r\n52.34,,,,,scattered clouds\r\n60.06,,,,,scattered clouds\r\n68.2,,,,,scattered clouds\r\n72.21,,,,,few clouds\r\n75.0,,,,,few clouds\r\n75.81,,,,,few clouds\r\n75.47,,,,,few clouds\r\n74.32,,,,,few clouds\r\n72.86,,,,,few clouds\r\n67.44,,,,,scattered clouds\r\n66.24,,,,,scattered clouds\r\n64.18,,,,,scattered clouds\r\n64.35,,,,,scattered clouds\r\n61.81,,,,,few clouds\r\n58.68,,,,,few clouds\r\n56.48,,,,,few clouds\r\n55.08,,,,,sky is clear\r\n54.36,,,,,sky is clear\r\n54.99,,,,,sky is clear\r\n55.0,,,,,sky is clear\r\n54.66,,,,,sky is clear\r\n53.87,,,,,sky is clear\r\n53.02,,,,,sky is clear\r\n53.42,,,,,sky is clear\r\n57.52,,,,,sky is clear\r\n66.22,,,,,few clouds\r\n73.35,,,,,few clouds\r\n78.03,,,,,few clouds\r\n79.83,,,,,sky is clear\r\n77.68,,,,,sky is clear\r\n78.62,,,,,sky is clear\r\n74.84,,,,,few clouds\r\n73.58,,,,,few clouds\r\n69.75,,,,,few clouds\r\n65.59,,,,,few clouds\r\n60.37,,,,,few clouds\r\n59.81,,,,,scattered clouds\r\n57.58,,,,,scattered clouds\r\n56.86,,,,,scattered clouds\r\n55.69,,,,,scattered clouds\r\n54.18,,,,,broken clouds\r\n53.49,,,,,broken clouds\r\n52.77,,,,,broken clou ...

# %%
SDweather_df.to_csv("SDweather.csv")
